# %% [markdown]
# This can be run [run on Google Colab using this link](https://colab.research.google.com/github/CS7150/CS7150-Homework-2/blob/main/HW2_2_CIFAR10Classifier.ipynb)
#
# <font size='6'>**Homework 2.2: Neural Network CIFAR-10 Classification**</font>

# %% [markdown]
# <font size='5'>**Overview**</font>
#
# In this CS7150 assignment, our objective is to build a neural network featuring two fully-connected layers designed for classification purposes. We will evaluate the performance of this neural network by testing it on the CIFAR-10 dataset.
#
# This assignment adheres to a standard classification setup, which encompasses the use of a dataloader to load labeled image data in a natural form and training the model in a minibatch-based fashion.
#
# **Your assignment**: Your responsibility throughout this notebook is to thoroughly review the content and address all the conceptual and technical questions identified within the sections marked with "Task" headers and "TODO:" comments in the code.

# %% [markdown]
# <font size='5'>**I) Setup**</font>

# %%
import os
import torch
from torch import nn
from torchvision.datasets import CIFAR10
from torchvision.transforms import Compose, ToTensor
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

# %% [markdown]
# <font size='4'>**Device Setup**</font>

# %% [markdown]
# We aim to enable model training on a GPU to expedite our computations. First, we'll check whether torch.cuda is accessible; if it is, we will utilize the GPU; otherwise, we will continue to using the CPU.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %% [markdown]
# <font size='4'>**Loading CIFAR-10 Data**</font>

# %% [markdown]
# The CIFAR-10 dataset comprises a collection of 60,000 32x32 color images distributed across ten distinct classes. These classes correspond to various objects and include airplanes, cars, birds, cats, deer, dogs, frogs, horses, ships, and trucks. Within each class, there are precisely 6,000 images.

# %%
# downloading cifar10 into folder
data_dir = 'cifar10_data' # make sure that this folder is created in your working dir

#TODO: Fill out train_data and test_data variables using CIFAR10 (i.e., torchvision.datasets.CIFAR)
train_data = CIFAR10(data_dir, train=True, download=True, transform=Compose([ToTensor()]))
test_data = CIFAR10(data_dir, train=False, download=True, transform=Compose([ToTensor()]))
#train_data = None
#test_data = None
print(f'Datatype of the dataset object: {type(train_data)}')
# check the length of dataset
print(f'Number of samples in training data: {len(train_data)}')
print(f'Number of samples in test data: {len(test_data)}')
# Check the format of dataset
print(f'Format of the dataset: \n {train_data}')
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to cifar10_data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:03<00:00, 43346575.01it/s]
# Extracting cifar10_data/cifar-10-python.tar.gz to cifar10_data
# Files already downloaded and verified
# Datatype of the dataset object: <class 'torchvision.datasets.cifar.CIFAR10'>
# Number of samples in training data: 50000
# Number of samples in test data: 10000
# Format of the dataset:
#  Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: cifar10_data
#     Split: Train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#            )

# %% [markdown]
# ### <font size='4'>**Displaying Loaded Dataset**</font>

# %%
fig = plt.figure()
for i in range(6):
    plt.subplot(2, 3, i+1)
    plt.tight_layout()
    plt.imshow(train_data[i][0][0], cmap='gray', interpolation='none')
    plt.title("Class Label: {}".format(train_data[i][1]))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ## <font size='5'>**II) Building a Neural Network**</font>

# %% [markdown]
# ### <font size='4'>**1) Defining `CIFAR10Classifier` class**</font>

# %% [markdown]
# <font size='4' color='Red'>Task 1.1 - Defining `CIFAR10Classifier` class (4 points)</font>
#
# In the following class, make adjustments to the following attributes: flatten, hidden_size, class_size, and linear_relu_stack. Ensure that the linear_relu_stack consists of a minimum of two linear layers combined with a non-linear activation layer.

# %%
class CIFAR10Classifier(nn.Module):
    def __init__(self):
        super(CIFAR10Classifier, self).__init__()
        ########################################################################
        # TODO: Complete the following variables as instructed earlier
        ########################################################################
        self.flatten = nn.Flatten()
        self.hidden_size = 128
        self.class_size = 10
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(3 * 32 * 32, self.hidden_size),
            nn.BatchNorm1d(self.hidden_size),
            nn.ReLU(),
            nn.Linear(self.hidden_size, self.hidden_size // 2),
            nn.BatchNorm1d(self.hidden_size // 2),
            nn.ReLU(),
            nn.Linear(self.hidden_size // 2, self.class_size),
            nn.BatchNorm1d(self.class_size)
        )
        ########################################################################
        #                             END OF YOUR CODE                         #
        ########################################################################

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %% [markdown]
# ### <font size='4'>**2) Training a Neural Network**</font>

# %% [markdown]
# <font size='4' color='Red'>Task 1.2 - Defining parameters (3 points)</font>

# %% [markdown]
# Let's create an instance of `CIFAR10Classifier` and move it to the device. After doing so, we define the following hyperparameters for training:
#
# - **Number of Epochs**: This signifies the number of iterations over the dataset.
# - **Batch Size**: It represents the number of data samples that propagate through the network before parameter updates.
# - **Learning Rate**: This parameter determines the extent of model parameter updates during each batch/epoch. Smaller values lead to slower learning, while larger values may introduce instability during training.
#
# **Your Task**:
#
# 1. Set `learning_rate` to 1e-3, `batch_size` to 64, and `epochs` to 10 initially. Experiment with different values and retain the final choices that yield the highest testing accuracy.
#
# 2. Select an appropriate loss function. You should experiment with different options, such as `CrossEntropyLoss()`, `MSELoss()`, and any others, and choose the one that best suits the task.
#
# 3. Define the `optimizer` variable using any optimizer function (e.g., SGD, Adam, etc.). Be sure to explore different parameter values within the chosen optimizer function.
#
# 4. Remember to record your ultimate choices for each variable that contribute to achieving the best performance for your `CIFAR10Classifier`. To receive full credit for this assignment, your model should attain a classification accuracy of over 50% on the test set.

# %%
model = CIFAR10Classifier().to(device)
model.requires_grad_(True)

########################################################################
# TODO: Complete the following variables as instructed earlier
########################################################################

learning_rate = 1e-3
batch_size = 64
epochs = 10
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

########################################################################
#                             END OF YOUR CODE                         #
########################################################################

# %% [markdown]
# ### <font size='4'>**3) Train Loop**</font>

# %%
train_dataloader = DataLoader(train_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

# %% [markdown]
# In the above cell, we used a Dataloader to create batches for training and testing data. For each batch of size indicated in the batch_size hyperparameter, we perform backprop and update the model parameters' weights and biases.
#
# In the following cell, we define our train_loop.

# %%
def train_loop(dataloader, model, loss_fn, optimizer, print_log=True):
    size = len(dataloader.dataset)
    correct = 0
    training_acc = 0
    training_loss = 0
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X.to(device))
        loss = loss_fn(pred, y.to(device))
        correct += (pred.argmax(1) == y.to(device)).type(torch.float).sum().item()

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if (print_log==True) and (batch % 100 == 0):
            loss, current = loss.item(), batch * len(X)
            training_loss = loss
            print(f"""Training loop: loss: {loss:>7f}  [{current:>5d}/{size:>5d}]""")
    if (print_log==True):
        correct /= size
        training_acc = 100*correct
        print(f"""Training Accuracy: {training_acc:>0.1f}%""")
    return training_acc, training_loss

# %% [markdown]
# ### <font size='4'>**4) Test Loop**</font>

# %% [markdown]
# In the test loop, we iterate over the test dataset to check if model performance is improving.

# %%
def test_loop(dataloader, model, loss_fn, print_log=True):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X.to(device))
            test_loss += loss_fn(pred, y.to(device)).item()
            correct += (pred.argmax(1) == y.to(device)).type(torch.float).sum().item()

    test_loss /= num_batches
    correct /= size
    testing_acc = 100*correct
    if (print_log==True):
        print(f"Testing Accuracy: {testing_acc:>0.1f}%, Avg loss: {test_loss:>8f} \n")
    return testing_acc, test_loss

# %% [markdown]
# ### <font size='4'>**5) Running the loops**</font>

# %% [markdown]
# We run our loops for a certain number of times, which is indicated in the 'epoch' hyperparameter that we defined earlier. In the following cell, we run both our training and testing loop to see how our training and testing accuracies change over time.

# %%
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    train_loop(train_dataloader, model, loss_fn, optimizer)
    test_loop(test_dataloader, model, loss_fn)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Training
# Training loop: loss: 1.140968  [44800/50000]
# Training Accuracy: 60.4%
# Testing Accuracy: 51.2%, Avg loss: 1.411556
#
# Epoch 8
# -------------------------------
# Training loop: loss: 1.073407  [    0/50000]
# Training loop: loss: 1.073202  [ 6400/50000]
# Training loop: loss: 0.864365  [12800/50000]
# Training loop: loss: 1.164616  [19200/50000]
# Training loop: loss: 1.054248  [25600/50000]
# Training loop: loss: 1.216466  [32000/50000]
# Training loop: loss: 1.224992  [38400/50000]
# Training loop: loss: 1.117713  [44800/50000]
# Training Accuracy: 62.1%
# Testing Accuracy: 50.7%, Avg loss: 1.429216
#
# Epoch 9
# -------------------------------
# Training loop: loss: 0.978177  [    0/50000]
# Training loop: loss: 1.030947  [ 6400/50000]
# Training loop: loss: 0.827833  [12800/50000]
# Training loop: loss: 1.158086  [19200/50000]
# Training loop: loss: 0.995745  [25600/50000]
# Training loop: loss: 1.183025  [32000/50000]
# Training loop: loss: 1.154380  [38400/50000]
# Training loop: loss: 1.096512  [44800/50000]
# Training Accuracy: 63.6%
# Testing Accuracy: 50.5%, Avg loss: 1.444118
#
# Epoch 10
# -------------------------------
# Training loop: loss: 0.933865  [    0/50000]
# Training loop: loss: 1.012092  [ 6400/50000]
# Training loop: loss: 0.786715  [12800/50000]
# Training loop: loss: 1.126095  [19200/50000]
# Training loop: loss: 0.935264  [25600/50000]
# Training loop: loss: 1.123760  [32000/50000]
# Training loop: loss: 1.136938  [38400/50000]
# Training loop: loss: 1.042100  [44800/50000]
# Training Accuracy: 65.1%
# Testing Accuracy: 50.4%, Avg loss: 1.473403
#
# Done!

# %% [markdown]
# To improve the CIFAR10Classifier, I made modifications to the architecture. Specifically, I added batchnorm to each layer, and I reduced the number of hidden parameters by half after the first linear layer.

# %% [markdown]
# ## <font size='5'>**III) Fine Tuning Hyperparameters**</font>

# %% [markdown]
# Adjusting the hyperparameters and gaining a deeper understanding of how they impact the ultimate performance is a substantial aspect of working with neural networks. Therefore, we encourage you to gain practical experience in this regard.

# %% [markdown]
# In this task, your goal is to play around with different settings for various options like layer size, batch size, learning rate. You should also experiment with optimizer hyperparameters including momentum, weight decay and more.
#
# To understand how these choices affect your model's performance, you'll create at least three graphs. Each graph will show how changing one of these options (except for epochs) impacts how well your model learns and predicts.

# %% [markdown]
# ## <font size='4'>**Example** - We've given you an example code for changing number of epochs so you can see how it's done.</font>

# %%
learning_rate = 1e-3
batch_size = 64
epochs = [1, 5, 10, 15, 20, 25]
momentum = 0
weight_decay = 0
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for e in epochs: #Would change this to reflect whatever hyperparameter you would be testing
    # Model
    model = CIFAR10Classifier().to(device)
    model.requires_grad_(True)
    # Optimizer
    optimizer = torch.optim.SGD(model.parameters(),
                            lr = learning_rate,
                            momentum = momentum,
                            weight_decay = weight_decay,
                            dampening= dampening)
    # Loss Func
    loss_fn = nn.CrossEntropyLoss()
    # Dataloaders
    train_dataloader = DataLoader(train_data, batch_size=batch_size)
    test_dataloader = DataLoader(test_data, batch_size=batch_size)
    final_train_acc = 0
    final_test_acc = 0
    final_test_loss = 0
    for t in range(e):
        # print(f"Currently running epoch {t+1}")
        training_acc, train_loss = train_loop(train_dataloader, model, loss_fn, optimizer, print_log=True)
        testing_acc, test_loss =  test_loop(test_dataloader, model, loss_fn, print_log=True)
        final_test_acc = testing_acc
        final_test_loss = test_loss
        final_train_acc = training_acc
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)
plt.plot(epochs,test_losses, color ='tab:red', label='testing loss')
plt.plot(epochs,test_accs, color ='tab:blue', label='testing accuracy')
plt.plot(epochs,training_accs, color ='tab:green', label='training accuracy')
plt.legend()
print("Done!")
# Out:
# Training loop: loss: 2.734413  [    0/50000]
# Training loop: loss: 1.939834  [ 6400/50000]
# Training loop: loss: 1.712178  [12800/50000]
# Training loop: loss: 1.903495  [19200/50000]
# Training loop: loss: 1.860232  [25600/50000]
# Training loop: loss: 1.898784  [32000/50000]
# Training loop: loss: 1.858196  [38400/50000]
# Training loop: loss: 1.679286  [44800/50000]
# Training Accuracy: 34.1%
# Testing Accuracy: 39.3%, Avg loss: 1.735700
#
# Training loop: loss: 2.489227  [    0/50000]
# Training loop: loss: 2.020111  [ 6400/50000]
# Training loop: loss: 1.673004  [12800/50000]
# Training loop: loss: 1.960843  [19200/50000]
# Training loop: loss: 1.863389  [25600/50000]
# Training loop: loss: 1.883969  [32000/50000]
# Training loop: loss: 1.871789  [38400/50000]
# Training loop: loss: 1.688187  [44800/50000]
# Training Accuracy: 33.5%
# Testing Accuracy: 39.3%, Avg loss: 1.748985
#
# Training loop: loss: 1.752977  [    0/50000]
# Training loop: loss: 1.745493  [ 6400/50000]
# Training loop: loss: 1.485550  [12800/50000]
# Training loop: loss: 1.759512  [19200/50000]
# Training loop: loss: 1.702254  [25600/50000]
# Training loop: loss: 1.792880  [32000/50000]
# Training loop: loss: 1.706276  [38400/50000]
# Training loop: loss: 1.593571  [44800/50000]
# Training Accuracy: 41.7%
# Testing Accuracy: 42.1%, Avg loss: 1.674043
#
# Training loop: loss: 1.676055  [    0/50000]
# Training loop: loss: 1.654620  [ 6400/50000]
# Training loop: loss: 1.397782  [12800/50000]
# Training loop: loss: 1.709830  [19200/50000]
# Training loop: loss: 1.611367  [25600/50000]
# Training loop: loss: 1.715142  [32000/50000]
# Training loop: loss: 1.638086  [38400/50000]
# Training loop: loss: 1.567046  [44800/50000]
# Training Accuracy: 45.0%
# Testing Accuracy: 43.9%, Avg loss: 1.632585
#
# Training loop: loss: 1.631887  [    0/50000]
# Training loop: loss: 1.600303  [ 6400/50000]
# Training loop: loss: 1.349137  [12800/50000]
# Training loop: loss: 1.630777  [19200/50000]
# Training loop: loss: 1.542411  [25600/50000]
# Training loop: loss: 1.677207  [32000/50000]
# Training loop: loss: 1.603973  [38400/50000]
# Training loop: loss: 1.549344  [44800/50000]
# Training Accuracy: 47.1%
# Testing Accuracy: 44.9%, Avg loss: 1.604679
#
# Training loop: loss: 1.583037  [    0/50000]
# Training loop: loss: 1.571267  [ 6400/50000]
# Training loop: loss: 1.316164  [12800/50000]
# Training loop: loss: 1.587999  [19200/50000]
# Training loop: loss: 1.497272  [25600/50000]
# Training loop: loss: 1.644361  [32000/50000]
# Training loop: loss: 1.564743  [38400/50000]
# Training loop: loss: 1.527363  [44800/50000]
# Training Accuracy: 48.7%
# Testing Accuracy: 45.3%, Avg loss: 1.583418
#
# Done!

# %% [markdown]
# <font size='4' color='Red'>Task 1.3 - Experiment 1 (2 point)</font>

# %% [markdown]
# $$\text{I am tuning weight decay hyperparameter for better performance}$$

# %%
############################################################################
# TODO: Implement your code here
############################################################################
learning_rate = 1e-3
batch_size = 64
epochs = 10
momentum = 0
weight_decays = [1e-4, 1e-3, 1e-2, 1e-1]
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for w in weight_decays: #Would change this to reflect whatever hyperparameter you would be testing
    # Model
    model = CIFAR10Classifier().to(device)
    model.requires_grad_(True)
    # Optimizer
    optimizer = torch.optim.SGD(model.parameters(),
                            lr = learning_rate,
                            momentum = momentum,
                            weight_decay = w,
                            dampening= dampening)
    # Loss Func
    loss_fn = nn.CrossEntropyLoss()
    # Dataloaders
    train_dataloader = DataLoader(train_data, batch_size=batch_size)
    test_dataloader = DataLoader(test_data, batch_size=batch_size)
    final_train_acc = 0
    final_test_acc = 0
    final_test_loss = 0
    for t in range(epochs):
        # print(f"Currently running epoch {t+1}")
        training_acc, train_loss = train_loop(train_dataloader, model, loss_fn, optimizer, print_log=True)
        testing_acc, test_loss =  test_loop(test_dataloader, model, loss_fn, print_log=True)
        final_test_acc = testing_acc
        final_test_loss = test_loss
        final_train_acc = training_acc
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)
plt.plot(weight_decays, test_losses, color ='tab:red', label='testing loss')
plt.plot(weight_decays, test_accs, color ='tab:blue', label='testing accuracy')
plt.plot(weight_decays, training_accs, color ='tab:green', label='training accuracy')
plt.legend()
print("Done!")


############################################################################
#                             END OF YOUR CODE                             #
############################################################################
# Out:
# Done!

# %% [markdown]
# <font size='4' color='Red'>Task 1.3 - Experiment 2 (2 point)</font>

# %% [markdown]
# $$\text{I am tuning momentum hyperparameter for better performance}$$

# %%
############################################################################
# TODO: Implement your code here
############################################################################
learning_rate = 1e-3
batch_size = 64
epochs = 10
momentums = [0.1, 0.5, 0.9, 0.99]
weight_decay = 0
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for m in momentums: #Would change this to reflect whatever hyperparameter you would be testing
    # Model
    model = CIFAR10Classifier().to(device)
    model.requires_grad_(True)
    # Optimizer
    optimizer = torch.optim.SGD(model.parameters(),
                            lr = learning_rate,
                            momentum = m,
                            weight_decay = weight_decay,
                            dampening= dampening)
    # Loss Func
    loss_fn = nn.CrossEntropyLoss()
    # Dataloaders
    train_dataloader = DataLoader(train_data, batch_size=batch_size)
    test_dataloader = DataLoader(test_data, batch_size=batch_size)
    final_train_acc = 0
    final_test_acc = 0
    final_test_loss = 0
    for t in range(epochs):
        # print(f"Currently running epoch {t+1}")
        training_acc, train_loss = train_loop(train_dataloader, model, loss_fn, optimizer, print_log=True)
        testing_acc, test_loss =  test_loop(test_dataloader, model, loss_fn, print_log=True)
        final_test_acc = testing_acc
        final_test_loss = test_loss
        final_train_acc = training_acc
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)
plt.plot(momentums,test_losses, color ='tab:red', label='testing loss')
plt.plot(momentums,test_accs, color ='tab:blue', label='testing accuracy')
plt.plot(momentums,training_accs, color ='tab:green', label='training accuracy')
plt.legend()
print("Done!")

############################################################################
#                             END OF YOUR CODE                             #
############################################################################
# Out:
# Training loop: loss: 2.867242  [    0/50000]
# Training loop: loss: 2.087733  [ 6400/50000]
# Training loop: loss: 1.660143  [12800/50000]
# Training loop: loss: 1.915083  [19200/50000]
# Training loop: loss: 1.738720  [25600/50000]
# Training loop: loss: 1.906519  [32000/50000]
# Training loop: loss: 1.892839  [38400/50000]
# Training loop: loss: 1.636812  [44800/50000]
# Training Accuracy: 34.5%
# Testing Accuracy: 40.2%, Avg loss: 1.722547
#
# Training loop: loss: 1.784705  [    0/50000]
# Training loop: loss: 1.700219  [ 6400/50000]
# Training loop: loss: 1.398408  [12800/50000]
# Training loop: loss: 1.756606  [19200/50000]
# Training loop: loss: 1.579482  [25600/50000]
# Training loop: loss: 1.745072  [32000/50000]
# Training loop: loss: 1.753343  [38400/50000]
# Training loop: loss: 1.528488  [44800/50000]
# Training Accuracy: 42.6%
# Testing Accuracy: 43.1%, Avg loss: 1.650843
#
# Training loop: loss: 1.715791  [    0/50000]
# Training loop: loss: 1.573062  [ 6400/50000]
# Training loop: loss: 1.310777  [12800/50000]
# Training loop: loss: 1.704122  [19200/50000]
# Training loop: loss: 1.520536  [25600/50000]
# Training loop: loss: 1.689404  [32000/50000]
# Training loop: loss: 1.697884  [38400/50000]
# Training loop: loss: 1.494736  [44800/50000]
# Training Accuracy: 45.5%
# Testing Accuracy: 44.3%, Avg loss: 1.609491
#
# Training loop: loss: 1.681984  [    0/50000]
# Training loop: loss: 1.500524  [ 6400/50000]
# Training loop: loss: 1.255063  [12800/50000]
# Training loop: loss: 1.675080  [19200/50000]
# Training loop: loss: 1.480667  [25600/50000]
# Training loop: loss: 1.649498  [32000/50000]
# Training loop: loss: 1.649056  [38400/50000]
# Training loop: loss: 1.444606  [44800/50000]
# Training Accuracy: 47.7%
# Testing Accuracy: 45.4%, Avg loss: 1.582625
#
# Training loop: loss: 1.651390  [    0/50000]
# Training loop: loss: 1.464033  [ 6400/50000]
# Training loop: loss: 1.217343  [12800/50000]
# Training loop: loss: 1.638421  [19200/50000]
# Training loop: loss: 1.429173  [25600/50000]
# Training loop: loss: 1.637118  [32000/50000]
# Training loop: loss: 1.586791  [38400/50000]
# Training loop: loss: 1.417576  [44800/50000]
# Training Accuracy: 49.5%
# Testing Accuracy: 46.0%, Avg loss: 1.564083
#
# Training loop: loss: 1.618612  [    0/50000]
# Training loop: loss: 1.440058  [ 6400/50000]
# Training loop: loss: 1.139442  [ 6400/50000]
# Training loop: loss: 0.816785  [12800/50000]
# Training loop: loss: 1.378504  [19200/50000]
# Training loop: loss: 1.113647  [25600/50000]
# Training loop: loss: 1.155110  [32000/50000]
# Training loop: loss: 1.099859  [38400/50000]
# Training loop: loss: 1.122465  [44800/50000]
# Training Accuracy: 61.1%
# Testing Accuracy: 49.8%, Avg loss: 1.448052
#
# Done!

# %% [markdown]
# <font size='4' color='Red'>Task 1.4 - Experiment 3 (2 point)</font>

# %% [markdown]
# $$\text{I am tuning batch size hyperparameter for better performance}$$

# %%
############################################################################
# TODO: Implement your code here
############################################################################
learning_rate = 1e-3
batch_sizes = [32, 64, 128, 256]
epochs = 10
momentum = 0
weight_decay = 0
dampening = 0

# Train and Test
test_accs = []
test_losses = []
training_accs = []
for b in batch_sizes: #Would change this to reflect whatever hyperparameter you would be testing
    # Model
    model = CIFAR10Classifier().to(device)
    model.requires_grad_(True)
    # Optimizer
    optimizer = torch.optim.SGD(model.parameters(),
                            lr = learning_rate,
                            momentum = momentum,
                            weight_decay = weight_decay,
                            dampening= dampening)
    # Loss Func
    loss_fn = nn.CrossEntropyLoss()
    # Dataloaders
    train_dataloader = DataLoader(train_data, batch_size=b)
    test_dataloader = DataLoader(test_data, batch_size=b)
    final_train_acc = 0
    final_test_acc = 0
    final_test_loss = 0
    for t in range(epochs):
        # print(f"Currently running epoch {t+1}")
        training_acc, train_loss = train_loop(train_dataloader, model, loss_fn, optimizer, print_log=True)
        testing_acc, test_loss =  test_loop(test_dataloader, model, loss_fn, print_log=True)
        final_test_acc = testing_acc
        final_test_loss = test_loss
        final_train_acc = training_acc
    test_accs.append(final_test_acc)
    test_losses.append(final_test_loss)
    training_accs.append(final_train_acc)
plt.plot(batch_sizes,test_losses, color ='tab:red', label='testing loss')
plt.plot(batch_sizes,test_accs, color ='tab:blue', label='testing accuracy')
plt.plot(batch_sizes,training_accs, color ='tab:green', label='training accuracy')
plt.legend()
print("Done!")

############################################################################
#                             END OF YOUR CODE                             #
############################################################################

############################################################################
#                             END OF YOUR CODE                             #
############################################################################
# Out:
# Training loop: loss: 2.416077  [    0/50000]
# Training loop: loss: 2.221234  [ 3200/50000]
# Training loop: loss: 1.883297  [ 6400/50000]
# Training loop: loss: 1.880971  [ 9600/50000]
# Training loop: loss: 1.643131  [12800/50000]
# Training loop: loss: 1.857074  [16000/50000]
# Training loop: loss: 1.912610  [19200/50000]
# Training loop: loss: 1.867697  [22400/50000]
# Training loop: loss: 1.775550  [25600/50000]
# Training loop: loss: 1.746572  [28800/50000]
# Training loop: loss: 1.800725  [32000/50000]
# Training loop: loss: 1.678859  [35200/50000]
# Training loop: loss: 1.857018  [38400/50000]
# Training loop: loss: 1.554056  [41600/50000]
# Training loop: loss: 1.728273  [44800/50000]
# Training loop: loss: 1.963745  [48000/50000]
# Training Accuracy: 35.4%
# Testing Accuracy: 41.0%, Avg loss: 1.700708
#
# Training loop: loss: 1.873916  [    0/50000]
# Training loop: loss: 1.699709  [ 3200/50000]
# Training loop: loss: 1.589326  [ 6400/50000]
# Training loop: loss: 1.577829  [ 9600/50000]
# Training loop: loss: 1.461504  [12800/50000]
# Training loop: loss: 1.669849  [16000/50000]
# Training loop: loss: 1.818131  [19200/50000]
# Training loop: loss: 1.673871  [22400/50000]
# Training loop: loss: 1.600276  [25600/50000]
# Training loop: loss: 1.635859  [28800/50000]
# Training loop: loss: 1.737396  [32000/50000]
# Training loop: loss: 1.574536  [35200/50000]
# Training loop: loss: 1.639414  [38400/50000]
# Training loop: loss: 1.477987  [41600/50000]
# Training loop: loss: 1.598629  [44800/50000]
# Training loop: loss: 1.935796  [48000/50000]
# Training Accuracy: 43.1%
# Testing Accuracy: 43.2%, Avg loss: 1.637310
#
# Training loop: loss: 1.780646  [    0/50000]
# Training loop: loss: 1.583755  [ 3200/50000]
# Training loop: loss: 1.482162  [ 6400/50000]
# Training loop: loss: 1.413114  [ 9600/50000]
# Training loop: loss: 1.428403  [12800/50000]
# Training loop: loss: 1.630890  [25600/50000]
# Training loop: loss: 1.576872  [38400/50000]
# Training Accuracy: 47.8%
# Testing Accuracy: 45.4%, Avg loss: 1.595347
#
# Training loop: loss: 1.586417  [    0/50000]
# Training loop: loss: 1.465296  [12800/50000]
# Training loop: loss: 1.599404  [25600/50000]
# Training loop: loss: 1.555640  [38400/50000]
# Training Accuracy: 48.9%
# Testing Accuracy: 45.8%, Avg loss: 1.580679
#
# Training loop: loss: 1.557711  [    0/50000]
# Training loop: loss: 1.440186  [12800/50000]
# Training loop: loss: 1.568410  [25600/50000]
# Training loop: loss: 1.535365  [38400/50000]
# Training Accuracy: 49.8%
# Testing Accuracy: 46.3%, Avg loss: 1.567573
#
# Training loop: loss: 1.534768  [    0/50000]
# Training loop: loss: 1.421643  [12800/50000]
# Training loop: loss: 1.544540  [25600/50000]
# Training loop: loss: 1.518921  [38400/50000]
# Training Accuracy: 50.7%
# Testing Accuracy: 46.7%, Avg loss: 1.556949
#
# Training loop: loss: 1.511782  [    0/50000]
# Training loop: loss: 1.398303  [12800/50000]
# Training loop: loss: 1.518256  [25600/50000]
# Training loop: loss: 1.502820  [38400/50000]
# Training Accuracy: 51.4%
# Testing Accuracy: 46.8%, Avg loss: 1.547929
#
# Training loop: loss: 2.713887  [    0/50000]
# Training loop: loss: 2.000920  [25600/50000]
# Training Accuracy: 27.3%
# Testing Accuracy: 33.4%, Avg loss: 1.908891
#
# Training loop: loss: 1.951290  [    0/50000]
# Training loop: loss: 1.834415  [25600/50000]
# Training Accuracy: 35.8%
# Testing Accuracy: 37.2%, Avg loss: 1.806043
#
# Training loop: loss: 1.822755  [    0/50000]
# Training loop: loss: 1.756734  [25600/50000]
# Training Accuracy: 38.9%
# Testing Accuracy: 39.2%, Avg loss: 1.750622
#
# Training loop: loss: 1.756941  [    0/50000]
# Training loop: loss: 1.712057  [25600/50000]
# Training Accuracy: 40.9%
# Testing Accuracy: 41.0%, Avg loss: 1.714574
#
# Training loop: loss: 1.713693  [    0/50000]
# Training loop: loss: 1.681769  [25600/50000]
# Training Accuracy: 42.5%
# Testing Accuracy: 42.2%, Avg loss: 1.687433
#
# Training loop: loss: 1.683213  [    0/50000]
# Training loop: loss: 1.660065  [25600/50000]
# Training Accuracy: 43.8%
# Testing Accuracy: 42.8%, Avg loss: 1.666324
#
# Training loop: loss: 1.655756  [    0/50000]
# Training loop: loss: 1.640631  [25600/50000]
# Training Accuracy: 44.9%
# Testing Accuracy: 43.5%, Avg loss: 1.649219
#
# Training loop: loss: 1.636912  [    0/50000]
# Training loop: loss: 1.621937  [25600/50000]
# Training Accuracy: 45.7%
# Testing Accuracy: 44.0%, Avg loss: 1.634398
#
# Training loop: loss: 1.618994  [    0/50000]
# Training loop: loss: 1.606069  [25600/50000]
# Training Accuracy: 46.4%
# Testing Accuracy: 44.4%, Avg loss: 1.621720
#
# Training loop: loss: 1.602059  [    0/50000]
# Training loop: loss: 1.589936  [25600/50000]
# Training Accuracy: 47.2%
# Testing Accuracy: 44.8%, Avg loss: 1.611397
#
# Done!
